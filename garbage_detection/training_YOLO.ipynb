# %%
# !pip install ultralytics
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.99-py3-none-any.whl.metadata (39 kB)
# Collecting numpy<2.0.0,>=1.23.0 (from ultralytics)
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from ultralytics) (3.9.2)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=7.1.2 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from ultralytics) (2.32.3)
# Collecting scipy>=1.4.1 (from ultralytics)
#   Using cached scipy-1.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting torch>=1.8.0 (from ultralytics)
#   Using cached torch-2.4.1-cp312-cp312-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Using cached torchvision-0.19.1-cp312-cp312-manylinux1_x86_64.whl.metadata (6.0 kB)
# Requirement already satisfied: tqdm>=4.64.0 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from ultralytics) (5.9.0)
# Collecting py-cpuinfo (from ultralytics)
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting pandas>=1.1.4 (from ultralytics)
#   Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting seaborn>=0.11.0 (from ultralytics)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.8-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.54.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Collecting tzdata>=2022.7 (from pandas>=1.1.4->ultralytics)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Collecting filelock (from torch>=1.8.0->ultralytics)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Collecting sympy (from torch>=1.8.0->ultralytics)
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.8.0->ultralytics)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: jinja2 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Collecting fsspec (from torch>=1.8.0->ultralytics)
#   Using cached fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: setuptools in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (75.1.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch>=1.8.0->ultralytics)
#   Using cached triton-3.0.0-1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics)
#   Using cached nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.8.0->ultralytics)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading ultralytics-8.2.99-py3-none-any.whl (874 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.0/874.0 kB 598.1 kB/s eta 0:00:00 kB/s eta 0:00:01
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
# Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
# Using cached scipy-1.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.8 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached torch-2.4.1-cp312-cp312-manylinux1_x86_64.whl (797.0 MB)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Using cached triton-3.0.0-1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.5 MB)
# Using cached torchvision-0.19.1-cp312-cp312-manylinux1_x86_64.whl (7.0 MB)
# Downloading ultralytics_thop-2.0.8-py3-none-any.whl (26 kB)
# Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Installing collected packages: py-cpuinfo, mpmath, tzdata, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, fsspec, filelock, triton, scipy, pandas, opencv-python, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, seaborn, ultralytics-thop, torchvision, ultralytics
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.1
#     Uninstalling numpy-2.1.1:
#       Successfully uninstalled numpy-2.1.1
# Successfully installed filelock-3.16.1 fsspec-2024.9.0 mpmath-1.3.0 networkx-3.3 numpy-1.26.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.68 nvidia-nvtx-cu12-12.1.105 opencv-python-4.10.0.84 pandas-2.2.3 py-cpuinfo-9.0.0 scipy-1.14.1 seaborn-0.13.2 sympy-1.13.3 torch-2.4.1 torchvision-0.19.1 triton-3.0.0 tzdata-2024.1 ultralytics-8.2.99 ultralytics-thop-2.0.8
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (2.4.1)
# Requirement already satisfied: torchvision in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (0.19.1)
# Collecting torchaudio
#   Using cached https://download.pytorch.org/whl/cu118/torchaudio-2.4.1%2Bcu118-cp312-cp312-linux_x86_64.whl (3.3 MB)
# Requirement already satisfied: filelock in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (2024.9.0)
# Requirement already satisfied: setuptools in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (75.1.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.68)
# Requirement already satisfied: numpy in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/gobi/anaconda3/envs/yolo_model/lib/python3.12/site-packages (from sympy->torch) (1.3.0)
# Installing collected packages: torchaudio
# Successfully installed torchaudio-2.4.1+cu118

# %%
#freeing gpu memory
import torch
torch.cuda.empty_cache()

# %%
#training yolo model
# !yolo task=detect \
model=yolov8s.pt \
mode=train \
data=data_combined.yaml \
imgsz=512 \
device=0 \
epochs=100 \
batch=8 \
pretrained=True \
optimizer=AdamW \
verbose=True \
amp=False \
patience=30 \
dropout=0.5
# Out:
# New https://pypi.org/project/ultralytics/8.2.100 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.99 🚀 Python-3.12.5 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 3899MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=data_combined.yaml, epochs=100, time=None, patience=30, batch=8, imgsz=512, save=True, save_period=-1, cache=False, device=0, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=AdamW, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=False, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.5, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2118370  ultralytics.nn.modules.head.Detect           [6, [128, 256, 512]]
# Model summary: 225 layers, 11,137,922 parameters, 11,137,906 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /home/gobi/intel_hackathon/datasets/GARBAGE-CLASSIFICATION-3-1/t
# train: New cache created: /home/gobi/intel_hackathon/datasets/GARBAGE-CLASSIFICATION-3-1/train/labels.cache
# val: Scanning /home/gobi/intel_hackathon/datasets/GARBAGE-CLASSIFICATION-3-1/val
# val: New cache created: /home/gobi/intel_hackathon/datasets/GARBAGE-CLASSIFICATION-3-1/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: AdamW(lr=0.01, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      3.34G      1.557      2.248      1.612         40        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.284      0.301       0.23      0.131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      3.66G      1.471      2.041      1.558         37        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.432       0.35      0.332       0.21
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      3.89G      1.398      1.885      1.505         20        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.535      0.399      0.415      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      3.27G      1.347      1.763      1.467         40        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.579      0.421      0.451      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.89G      1.307      1.675      1.441         13        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.624      0.443      0.498      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      3.45G       1.29      1.609      1.418         20        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.645      0.464      0.522      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      3.97G      1.261      1.543      1.404         15        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.644      0.485       0.55      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      3.14G      1.239      1.487      1.386         30        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.666      0.496      0.566      0.401
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      3.34G      1.224      1.452      1.377         30        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860       0.69      0.514      0.593      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.89G      1.221      1.417      1.367        112        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.704      0.524       0.61      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100
0.606
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100       3.5G      1.015     0.8637      1.213         13        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.838        0.7        0.8      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      3.32G      1.014     0.8521      1.209         29        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.839      0.701      0.801      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      3.37G      1.012     0.8491      1.208         16        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860       0.84      0.702      0.802      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100       3.2G      1.016     0.8497      1.209         13        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.842      0.702      0.803      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      2.86G      1.006     0.8402      1.206         18        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.842      0.704      0.804      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      2.84G      1.006     0.8396      1.207         81        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.842      0.705      0.804      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      3.78G      1.009     0.8322      1.201         18        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.846      0.703      0.805      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      3.25G      1.005     0.8291      1.202         59        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.846      0.705      0.806      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      3.38G     0.9975      0.827        1.2         24        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.845      0.707      0.807      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100       3.4G     0.9995     0.8264        1.2         18        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.846      0.707      0.808      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      3.12G     0.9933     0.8118      1.194         21        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.846      0.708      0.809      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      2.85G     0.9959     0.8146      1.196         19        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.847       0.71       0.81      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      3.36G     0.9951     0.8065      1.194         21        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.847      0.711       0.81      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      3.14G     0.9876     0.8013      1.192         40        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.848      0.712      0.811      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      3.45G     0.9929     0.8059      1.193         12        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.846      0.713      0.812      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100       3.9G     0.9921     0.8038      1.192         13        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.847      0.715      0.813       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      3.77G     0.9924     0.7992       1.19         16        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.847      0.715      0.814      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      3.84G     0.9869     0.7898      1.186          7        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.849      0.716      0.814      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      3.91G     0.9847      0.788      1.186         13        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860       0.85      0.717      0.815      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      3.04G     0.9781     0.7813      1.186         67        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860       0.85      0.718      0.816      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      3.52G     0.9802     0.7805      1.185         29        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.851      0.719      0.817      0.624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      3.34G      0.978     0.7818      1.186         15        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.852      0.719      0.817      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      3.44G     0.9841     0.7769      1.187         67        512:

# %%
#continuing the interrupted training
# !yolo task=detect \
mode=train \
data=data_combined.yaml \
model=runs/detect/train/weights/last.pt \
resume=True
# Out:
# New https://pypi.org/project/ultralytics/8.2.101 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.99 🚀 Python-3.12.5 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 3899MiB)
# engine/trainer: task=detect, mode=train, model=runs/detect/train/weights/last.pt, data=data_combined.yaml, epochs=100, time=None, patience=30, batch=8, imgsz=512, save=True, save_period=-1, cache=False, device=0, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=AdamW, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=runs/detect/train/weights/last.pt, amp=False, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.5, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2118370  ultralytics.nn.modules.head.Detect           [6, [128, 256, 512]]
# Model summary: 225 layers, 11,137,922 parameters, 11,137,906 gradients, 28.7 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /home/gobi/intel_hackathon/datasets/GARBAGE-CLASSIFICATION-3-1/t
# val: Scanning /home/gobi/intel_hackathon/datasets/GARBAGE-CLASSIFICATION-3-1/val
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: AdamW(lr=0.01, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Resuming training runs/detect/train/weights/last.pt from epoch 82 to 100 total epochs
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100       3.4G     0.9982     0.8183      1.201         40        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.853      0.719      0.818      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      3.54G     0.9945      0.809      1.196         37        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.852       0.72      0.818      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      3.83G     0.9874     0.8023      1.193         20        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.852       0.72      0.818      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      3.27G     0.9863     0.8024      1.193         40        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.852      0.721      0.818      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      2.86G     0.9785     0.7939       1.19         13        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.852       0.72      0.818      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      3.44G     0.9898     0.7995      1.193         20        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.852      0.721      0.818      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      3.94G     0.9824      0.791      1.191         15        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.852      0.721      0.819      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      3.14G     0.9724       0.78      1.186         30        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.851      0.722      0.819      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      3.32G     0.9714     0.7791      1.186         30        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.852      0.722      0.819      0.626
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      3.46G     0.9213     0.6988      1.164          4        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.852      0.722      0.819      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      3.94G     0.9232     0.6899      1.162          7        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.852      0.723      0.819      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      3.21G     0.9095     0.6816      1.156         98        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.852      0.722      0.819      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      3.25G     0.9065      0.678      1.154          4        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.852      0.723       0.82      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      3.52G     0.8988     0.6627      1.149         28        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.854      0.722       0.82      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      3.77G      0.909     0.6679      1.155          6        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.854      0.723       0.82      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      3.52G     0.9071     0.6683      1.153          4        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.855      0.722       0.82      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      3.27G     0.8967      0.659      1.148          4        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.856      0.722       0.82      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      3.34G     0.9017     0.6567      1.149        291        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.857      0.721       0.82      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      3.66G     0.8997     0.6534      1.145          4        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.857      0.721       0.82      0.629
#
# 19 epochs completed in 5.677 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.99 🚀 Python-3.12.5 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 3899MiB)
# Model summary (fused): 168 layers, 11,127,906 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.857      0.721       0.82      0.629
#          BIODEGRADABLE       2219      43932      0.839      0.585      0.721      0.433
#              CARDBOARD       1434       4563       0.83      0.622      0.748      0.591
#                  GLASS       3335       9695      0.909      0.779      0.875      0.712
#                  METAL       2036       6396      0.865      0.817      0.876      0.679
#                  PAPER       1207       2934      0.856       0.81      0.885       0.74
#                PLASTIC       1134       4340      0.843      0.714      0.817      0.618
# Speed: 0.4ms preprocess, 8.6ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
#validating the model
# !yolo task=detect \
mode=val \
model=runs/detect/train/weights/best.pt \
data=data_combined.yaml
# Out:
# Ultralytics YOLOv8.2.99 🚀 Python-3.12.5 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 3899MiB)
# Model summary (fused): 168 layers, 11,127,906 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /home/gobi/intel_hackathon/datasets/GARBAGE-CLASSIFICATION-3-1/val
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      10031      71860      0.857      0.721       0.82      0.629
#          BIODEGRADABLE       2219      43932      0.839      0.585      0.721      0.433
#              CARDBOARD       1434       4563       0.83      0.622      0.748      0.591
#                  GLASS       3335       9695      0.909      0.779      0.875      0.712
#                  METAL       2036       6396      0.865      0.817      0.876      0.679
#                  PAPER       1207       2934      0.856       0.81      0.885       0.74
#                PLASTIC       1134       4340      0.843      0.714      0.817      0.618
# Speed: 0.4ms preprocess, 11.6ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#predicting on sample images
# !yolo task=detect \
mode=predict \
model=runs/detect/train/weights/best.pt \
conf=0.4 \
source=samples
# Out:
# Ultralytics YOLOv8.2.99 🚀 Python-3.12.5 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 3899MiB)
# Model summary (fused): 168 layers, 11,127,906 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/9 /home/gobi/intel_hackathon/samples/WhatsApp Image 2024-09-26 at 10.12.46 AM.jpeg: 288x512 1 PAPER, 26.7ms
# image 2/9 /home/gobi/intel_hackathon/samples/WhatsApp Image 2024-09-26 at 10.13.22 AM.jpeg: 512x256 1 METAL, 1 PAPER, 1 PLASTIC, 34.6ms
# image 3/9 /home/gobi/intel_hackathon/samples/sample.jpg: 512x512 4 GLASSs, 1 PAPER, 13.6ms
# image 4/9 /home/gobi/intel_hackathon/samples/sample2.jpg: 352x512 1 GLASS, 3 PLASTICs, 33.2ms
# image 5/9 /home/gobi/intel_hackathon/samples/sample3.jpg: 512x512 12 GLASSs, 13 PLASTICs, 15.2ms
# image 6/9 /home/gobi/intel_hackathon/samples/sample4.jpeg: 384x512 (no detections), 27.3ms
# image 7/9 /home/gobi/intel_hackathon/samples/sample5.png: 320x512 1 PLASTIC, 27.3ms
# image 8/9 /home/gobi/intel_hackathon/samples/sample6.jpg: 512x416 37 PLASTICs, 28.9ms
# image 9/9 /home/gobi/intel_hackathon/samples/sample7.jpg: 288x512 6 PAPERs, 1 PLASTIC, 10.4ms
# Speed: 1.7ms preprocess, 24.1ms inference, 13.5ms postprocess per image at shape (1, 3, 288, 512)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
